# %% [markdown]
# # Final GPU Benchmark (Top 10 Classes)

# %%
import sys, os
sys.path.insert(0, os.path.abspath('../src'))
from utils.config import CFG
CFG.DEVICE = 'cuda' if 'True' == 'True' else 'cpu'
CFG.QUANTUM_DEVICE = 'lightning.qubit'
CFG.CLASSES = ['tomato_tomato_yellowleaf_curl_virus', 'tomato_bacterial_spot', 'potato_early_blight', 'tomato_late_blight', 'apple_apple_scab', 'grape_black_rot', 'apple_cedar_apple_rust', 'tomato_spider_mites_two_spotted_spider_mite', 'tomato_target_spot', 'grape_esca_black_measles']
CFG.NUM_CLASSES = 10
print(f'Using Device: {CFG.DEVICE}')
print(f'Using Quantum Device: {CFG.QUANTUM_DEVICE}')
# Out:
# Using Device: cuda
# Using Quantum Device: lightning.qubit

# %%
from data.loader import load_dataset
from data.preprocess import build_dataloaders
from training.train import train_hybrid
from training.evaluate import evaluate_model, benchmark_report

train_rec, val_rec, test_rec = load_dataset(max_per_class=400)
train_loader, val_loader, test_loader = build_dataloaders(train_rec, val_rec, test_rec, batch_size=32)
model, history = train_hybrid(train_loader, val_loader, epochs=30)
results = evaluate_model(model, test_loader, 'Final Hybrid VQC (GPU)')
print(f'\nFinal Accuracy: {results["accuracy"]:.4f}')
# Out:
# C:\Users\balaj\AppData\Local\Programs\Python\Python38\lib\site-packages\pennylane_lightning\lightning_qubit\lightning_qubit.py:822: UserWarning: Pre-compiled binaries for lightning.qubit are not available. Falling back to using the Python-based default.qubit implementation. To manually compile from source, follow the instructions at https://pennylane-lightning.readthedocs.io/en/latest/installation.html.
#   warn(
# Dataset loaded → train: 2800, val: 400, test: 800
#   Train class distribution:
#     [0] tomato_tomato_yellowleaf_curl_virus → 284 images
#     [1] tomato_bacterial_spot          → 279 images
#     [2] potato_early_blight            → 291 images
#     [3] tomato_late_blight             → 298 images
#     [4] apple_apple_scab               → 294 images
#     [5] grape_black_rot                → 269 images
#     [6] apple_cedar_apple_rust         → 267 images
#     [7] tomato_spider_mites_two_spotted_spider_mite → 269 images
# ...

# %%
C:\Users\balaj\AppData\Local\Programs\Python\Python38\lib\site-packages\pennylane_lightning\lightning_qubit\lightning_qubit.py:822: UserWarning: Pre-compiled binaries for lightning.qubit are not available. Falling back to using the Python-based default.qubit implementation. To manually compile from source, follow the instructions at https://pennylane-lightning.readthedocs.io/en/latest/installation.html.
  warn(
Dataset loaded → train: 2800, val: 400, test: 800
  Train class distribution:
    [0] tomato_tomato_yellowleaf_curl_virus → 284 images
    [1] tomato_bacterial_spot          → 279 images
    [2] potato_early_blight            → 291 images
    [3] tomato_late_blight             → 298 images
    [4] apple_apple_scab               → 294 images
    [5] grape_black_rot                → 269 images
    [6] apple_cedar_apple_rust         → 267 images
    [7] tomato_spider_mites_two_spotted_spider_mite → 269 images
    [8] tomato_target_spot             → 276 images
    [9] grape_esca_black_measles       → 273 images
  DataLoaders built → train: 2800, val: 400, test: 800
C:\Users\balaj\AppData\Local\Programs\Python\Python38\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
  warnings.warn(
C:\Users\balaj\AppData\Local\Programs\Python\Python38\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
  warnings.warn(msg)

QuantumCrop Hybrid VQC — 67858 trainable parameters
  Qubits : 6  |  Layers : 3  |  Classes : 10
  Device : cuda  |  Quantum : lightning.qubit
  Epoch   1/30 | Train Loss: 2.2172 | Val Loss: 1.9758 | Val Acc: 0.2900 ✓ best
  Epoch   5/30 | Train Loss: 0.6090 | Val Loss: 0.4600 | Val Acc: 0.8325
  Epoch  10/30 | Train Loss: 0.3845 | Val Loss: 0.2440 | Val Acc: 0.9100
  Epoch  15/30 | Train Loss: 0.2863 | Val Loss: 0.1945 | Val Acc: 0.9250 ✓ best
  Epoch  20/30 | Train Loss: 0.2441 | Val Loss: 0.1991 | Val Acc: 0.9375 ✓ best
  Epoch  25/30 | Train Loss: 0.1982 | Val Loss: 0.1796 | Val Acc: 0.9450
  Epoch  30/30 | Train Loss: 0.2253 | Val Loss: 0.1764 | Val Acc: 0.9425

Hybrid VQC training complete. Best val accuracy: 0.9525
Best model saved → C:\Files\PROJECTS\QuantumCrop\outputs\models\hybrid_vqc_best.pt
c:\files\projects\quantumcrop\src\training\train.py:124: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
  model.load_state_dict(torch.load(save_path, map_location=device))

Final Hybrid VQC (GPU) Results:
  Accuracy  : 0.9213
  Precision : 0.9243
  Recall    : 0.9210
  Macro F1  : 0.9210

                                             precision    recall  f1-score   support

        tomato_tomato_yellowleaf_curl_virus       0.97      0.92      0.95        85
                      tomato_bacterial_spot       0.94      0.90      0.92        80
                        potato_early_blight       1.00      0.99      0.99        77
                         tomato_late_blight       0.87      0.94      0.90        69
                           apple_apple_scab       0.96      0.93      0.94        69
                            grape_black_rot       0.88      0.96      0.92        80
                     apple_cedar_apple_rust       0.99      0.98      0.98        86
tomato_spider_mites_two_spotted_spider_mite       0.82      0.96      0.88        89
                         tomato_target_spot       0.87      0.76      0.81        78
                   grape_esca_black_measles       0.96      0.89      0.92        87

                                   accuracy                           0.92       800
                                  macro avg       0.92      0.92      0.92       800
                               weighted avg       0.92      0.92      0.92       800


Final Accuracy: 0.9213
